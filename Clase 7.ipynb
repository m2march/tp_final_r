# %%
ns = 2:3000
promedios_set = rep(0, length(ns))
for (n in ns) {
    set.seed(1337)
    promedios_set[n - 1] = mean(runif(n, 0, 1))
}
plot(ns, promedios, type='l', xlab='n')
# Out:
# plot without title
